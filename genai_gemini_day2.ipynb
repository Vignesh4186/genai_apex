# %% [markdown]
# <a href="https://colab.research.google.com/github/Vignesh4186/genai_apex/blob/main/genai_gemini_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyA4tfzx6dbADxfJnTQ_qIljYNi4BcY44uI")

# %%
for i in genai.list_models():
  print(i.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-exp-1206
# models/gemini-exp-1121
# models/gemini-exp-1114
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# ...

# %%
model=genai.GenerativeModel("gemini-pro")

# %%
res=model.generate_content("district in tamilnadu")

# %%
print(res.text)
# Out:
#  தமிழ்நாட்டில் உள்ள மாவட்டங்கள்:
#
# * அரியலூர்
# * சென்னை
# * கோயம்புத்தூர்
# * கடலூர்
# * திண்டுக்கல்
# * தூத்துக்குடி
# * ஈரோடு
# * கோவை
# * கன்னியாகுமரி
# * கரூர்
# * கிருஷ்ணகிரி
# * மதுரை
# * நாகப்பட்டினம்
# * நீலகிரி
# * பெரம்பலூர்
# * புதுக்கோட்டை
# * ராமநாதபுரம்
# * சேலம்
# * சிவகங்கை
# * தஞ்சாவூர்
# * தென்காசி
# * தேனி
# * திருச்சிராப்பள்ளி
# * திருவண்ணாமலை
# * திருவாரூர்
# * தூத்துக்குடி
# * உதகமண்டலம்
# * வேலூர்
# * விழுப்புரம்
# * விருதுநகர்
# * தேனி

# %%
know=model.generate_content("what is gdp of tamilnadu and how it achieved it")
print(know.text)
# Out:
# **GDP of Tamil Nadu**
#
# As of 2022-23, the Gross Domestic Product (GDP) of Tamil Nadu is estimated to be approximately INR 14.93 lakh crore (USD 197 billion). This makes it the second largest state economy in India, after Maharashtra.
#
# **How Tamil Nadu Achieved its GDP**
#
# Tamil Nadu's economic success can be attributed to a combination of factors, including:
#
# **1. Strong Industrial Base:**
# * The state has a diversified industrial base, with key sectors including textiles, automobiles, heavy engineering, electronics, and pharmaceuticals.
# * It is home to major companies such as Hyundai Motors, Nokia, BMW, and Bosch.
#
# **2. Developed Infrastructure:**
# * Tamil Nadu has a well-developed infrastructure, including roads, ports, airports, and power plants.
# * It has some of the best highways and container ports in the country.
#
# **3. Skilled Workforce:**
# ...

# %%
internet=model.generate_content("what is arpanet")
print(internet.text)
# Out:
# **ARPANET** (**A**dvanced **R**esearch **P**rojects **A**gency **NET**work) was the first wide-area packet-switching network with distributed control. It was developed by the United States Department of Defense's Advanced Research Projects Agency (ARPA) from 1966 to 1990. ARPANET was initially designed to enable researchers at different locations to collaborate on projects, and it played a crucial role in the development of the Internet.
#
# **Key Features of ARPANET:**
#
# * **Packet-switching:** Data was divided into small packets (called datagrams) and sent individually over the network. This allowed multiple users to share the same transmission medium simultaneously.
# * **Decentralized control:** The network was not controlled by a central authority, but rather by a collection of autonomous nodes (computers), each responsible for its own routing decisions.
# ...

# %%
# !pip install -q -U google-generativeai

# %%
genai.configure(api_key="AIzaSyA4tfzx6dbADxfJnTQ_qIljYNi4BcY44uI")

# %%
import google.generativeai as genai

# %%
vision_model=genai.GenerativeModel("gemini-1.5-flash")

# %%
from PIL import Image
img=Image.open("/content/download.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>

# %%
res=vision_model.generate_content(["what the image telling",img])

# %%
print(res.text)
# Out:
# That's promotional art for the anime series **One Piece**.
#
# The image shows the main characters of the Straw Hat Pirates crew:
#
# * **Monkey D. Luffy:** The main protagonist, in the foreground.
# * **Roronoa Zoro:**  The swordsman.
# * **Nami:** The navigator.
# * **Usopp:** The sniper.
# * **Sanji:** The chef.
# * **Tony Tony Chopper:** The reindeer doctor (partially visible).
# * **Franky:** The shipwright (partially visible).
#
# The image prominently features the show's title, "ONE PIECE," in its distinctive font and logo.  The overall style is consistent with the anime's art direction, depicting a bright, adventurous, and action-oriented tone.
